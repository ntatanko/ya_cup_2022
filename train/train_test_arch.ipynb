# %%
import glob
import json
import os
import random as rnd
import shutil

import keras.backend as K
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from IPython.core.interactiveshell import InteractiveShell
from sklearn.model_selection import StratifiedGroupKFold
from tensorflow import keras
from tqdm import tqdm

from src.utils import (
    DataGenerator,
    euclidean_distance,
    loss,
    make_callbacks,
    make_model,
    plot_history,
)

InteractiveShell.ast_node_interactivity = "all"

# %%
class CFG:
    def __init__(
        self,
    ):
        self.seed = 39
        self.batch_size = 32
        self.img_size = (512, 81)
        self.n_chanels = 1
        self.n_folds = 6
        self.fold = 0
        self.norm = False
        self.pos_label = 0
        self.n_blocks = 4
        self.emb_len = 2048
        self.kernel_size = (5, 2)
        self.act_fn = "relu"
        self.batch_norm = False
        self.n_epochs = 1000
        self.input_shape = (self.img_size[0], self.img_size[1], self.n_chanels)

# %%
cfg = CFG()

# %%
root_dir = "/app/_data/artist_data/"
mod_dir = "/app/_data/artist_data/models/test_arch/constr_7/"

# %%
train = pd.read_csv(os.path.join(root_dir, "train.csv"))

# %% [markdown]
# ## train_val_split

# %%
gkf = StratifiedGroupKFold(n_splits=cfg.n_folds, shuffle=True, random_state=cfg.seed)
for n, (train_ids, val_ids) in enumerate(
    gkf.split(
        X=train[["artistid", "artistid_count"]],
        y=train["artistid_count"],
        groups=train["artistid"],
    )
):
    train.loc[val_ids, "fold"] = n
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:885: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=6.
#   warnings.warn(

# %%
artist_ids = train["artistid"].unique().tolist()
train_set = train[train["fold"] != cfg.fold]["artistid"].unique()
val_set = train[train["fold"] == cfg.fold]["artistid"].unique()
train_data, val_data = {}, {}
for art_id in tqdm(artist_ids):
    new_df = train.query("artistid == @art_id")
    paths = new_df["path"].values.tolist()
    tracks = new_df["trackid"].values.tolist()
    if art_id in train_set:
        train_data[art_id] = {
            "tracks": tracks,
            "paths": paths,
            "count": new_df.shape[0],
        }
    else:
        val_data[art_id] = {"tracks": tracks, "paths": paths, "count": new_df.shape[0]}
# Out:
# 100% 18468/18468 [00:42<00:00, 435.93it/s]

# %% [markdown]
# ## DataGenerator

# %%
train_gen = DataGenerator(
    data=train_data,
    img_size=cfg.img_size,
    batch_size=cfg.batch_size,
    norm=cfg.norm,
    n_chanels=cfg.n_chanels,
    shuffle=True,
    positive_label=cfg.pos_label,
)
val_gen = DataGenerator(
    data=val_data,
    img_size=cfg.img_size,
    batch_size=cfg.batch_size,
    norm=cfg.norm,
    n_chanels=cfg.n_chanels,
    shuffle=False,
    positive_label=cfg.pos_label,
)

# %%
ix = np.random.randint(train_gen.__len__())
imgs, targets = train_gen.__getitem__(ix)

# %%
train_gen.positive_label
train_gen.negative_label
# Out:
# 0
# 1

# %% [markdown]
# ## Build model

# %%
# model = make_model(
#     input_shape=cfg.input_shape,
#     n_blocks=cfg.n_blocks,
#     embedding_len=cfg.emb_len,
#     kernel_size=cfg.kernel_size,
#     activation_fn="relu",
#     batch_norm=cfg.batch_norm,
# )

# %%
# base_model = keras.applications.EfficientNetV2B0(
#     include_top=False,
#     weights=None,
#     input_shape=cfg.input_shape,
#     pooling=None,
#     include_preprocessing=False,
# )
# input = tf.keras.Input(shape=cfg.input_shape, dtype="float32")
# x = base_model(input)
# x = keras.layers.Flatten(name="flatten")(x)
# x = keras.layers.Dense(
#     cfg.emb_len, activation=cfg.act_fn, name=f"dense_{cfg.emb_len}"
# )(x)
# embedding_net = keras.Model(inputs=input, outputs=x, name=f"embedding")

# input_1 = keras.layers.Input(cfg.input_shape, name="img1")
# input_2 = keras.layers.Input(cfg.input_shape, name="img2")
# node1 = embedding_net(input_1)
# node2 = embedding_net(input_2)

# merge_layer = keras.layers.Lambda(euclidean_distance)([node1, node2])
# output_layer = keras.layers.Dense(1, activation="sigmoid")(merge_layer)
# model = keras.Model(inputs=[input_1, input_2], outputs=output_layer)

# %%
# model = effmod(input_shape=cfg.input_shape, embedding_len=cfg.emb_len)

# %%
input = tf.keras.Input(shape=cfg.input_shape, dtype="float32")
x = keras.layers.Conv2D(
    4,
    cfg.kernel_size,
    activation=cfg.act_fn,
    name="Conv2D_1",
)(input)
x = keras.layers.AveragePooling2D(pool_size=(2, 2), name=f"avg_pool_1")(x)

x = keras.layers.Conv2D(
    filters=16,
    kernel_size=cfg.kernel_size,
    activation=cfg.act_fn,
    name="Conv2D_2",
)(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2), name=f"avg_pool_2")(x)

x = keras.layers.Conv2D(
    filters=64,
    kernel_size=cfg.kernel_size,
    activation=cfg.act_fn,
    name="Conv2D_3",
)(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2), name=f"avg_pool_3")(x)

x = keras.layers.Conv2D(
    filters=256,
    kernel_size=cfg.kernel_size,
    activation=cfg.act_fn,
    name="Conv2D_4",
)(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2), name=f"avg_pool_4")(x)

# x = keras.layers.Conv2D(
#     filters=256,
#     kernel_size=cfg.kernel_size,
#     activation=cfg.act_fn,
#     name="Conv2D_5",
# )(x)
# x = keras.layers.AveragePooling2D(pool_size=(2, 2), name=f"avg_pool_5")(x)


x = keras.layers.Flatten(name="flatten")(x)
x = keras.layers.Dense(cfg.emb_len, activation=cfg.act_fn, name=f"dense_{cfg.emb_len}")(
    x
)
embedding_net = keras.Model(inputs=input, outputs=x, name=f"embedding")


input_1 = keras.layers.Input(cfg.input_shape, name="img1")
input_2 = keras.layers.Input(cfg.input_shape, name="img2")
node1 = embedding_net(input_1)
node2 = embedding_net(input_2)

merge_layer = keras.layers.Lambda(euclidean_distance)([node1, node2])
output_layer = keras.layers.Dense(1, activation="sigmoid")(merge_layer)
model = keras.Model(inputs=[input_1, input_2], outputs=output_layer)

# %%
callbacks = make_callbacks(
    path=mod_dir,
    monitor="val_loss",
    mode="min",
    reduce_patience=10,
    stop_patience=100,
)
model.compile(
    loss=loss(1),
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
)

# %%
if os.path.exists(mod_dir):
    shutil.rmtree(mod_dir)
if os.path.exists(f"/app/.tensorboard/{mod_dir.split('/')[-2]}/"):
    shutil.rmtree(f"/app/.tensorboard/{mod_dir.split('/')[-2]}/")

# %%
history = model.fit(
    x=train_gen,
    epochs=cfg.n_epochs,
    verbose="auto",
    callbacks=callbacks,
    validation_data=val_gen,
    shuffle=True,
    steps_per_epoch=len(train_data) // cfg.batch_size,
    validation_steps=len(val_data) // cfg.batch_size,
    validation_freq=1,
    max_queue_size=10,
    workers=10,
    use_multiprocessing=False,
)
# Out:
# Epoch 1/1000
# 479/480 [============================>.] - ETA: 0s - loss: 0.2271 - accuracy: 0.5781 - precision: 0.5428 - recall: 0.9667
# Epoch 1: val_loss improved from inf to 0.21359, saving model to /app/_data/artist_data/models/test_arch/constr_7/model.h5
# 480/480 [==============================] - 46s 87ms/step - loss: 0.2271 - accuracy: 0.5781 - precision: 0.5426 - recall: 0.9668 - val_loss: 0.2136 - val_accuracy: 0.6813 - val_precision: 0.6267 - val_recall: 0.9061 - lr: 0.0010
# Epoch 2/1000
# 480/480 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.7010 - precision: 0.6467 - recall: 0.8895
# Epoch 2: val_loss improved from 0.21359 to 0.19572, saving model to /app/_data/artist_data/models/test_arch/constr_7/model.h5
# 480/480 [==============================] - 42s 86ms/step - loss: 0.2054 - accuracy: 0.7010 - precision: 0.6467 - recall: 0.8895 - val_loss: 0.1957 - val_accuracy: 0.7275 - val_precision: 0.6762 - val_recall: 0.8738 - lr: 0.0010
# Epoch 3/1000
# 479/480 [============================>.] - ETA: 0s - loss: 0.1908 - accuracy: 0.7477 - precision: 0.7065 - recall: 0.8389
# Epoch 3: val_loss improved from 0.19572 to 0.18490, saving model to /app/_data/artist_data/models/test_arch/constr_7/model.h5
# 480/480 [==============================] - 43s 88ms/step - loss: 0.1908 - accuracy: 0.7475 - precision: 0.7066 - recall: 0.8386 - val_loss: 0.1849 - val_accuracy: 0.7578 - val_precision: 0.7129 - val_recall: 0.8449 - lr: 0.0010
# Epoch 4/1000
# 479/480 [============================>.] - ETA: 0s - loss: 0.1773 - accuracy: 0.7706 - precision: 0.7438 - recall: 0.8409
# Epoch 4: val_loss improved from 0.18490 to 0.17528, saving model to /app/_data/artist_data/models/test_arch/constr_7/model.h5
# 480/480 [==============================] - 42s 87ms/step - loss: 0.1773 - accuracy: 0.7705 - precision: 0.7439 - recall: 0.8408 - val_loss: 0.1753 - val_accuracy: 0.7767 - val_precision: 0.7544 - val_recall: 0.8139 - lr: 0.0010
# Epoch 5/1000
# 479/480 [============================>.] - ETA: 0s - loss: 0.1691 - accuracy: 0.7911 - precision: 0.7688 - recall: 0.8291
# Epoch 5: val_loss improved from 0.17528 to 0.16175, saving model to /app/_data/artist_data/models/test_arch/constr_7/model.h5
# 480/480 [==============================] - 42s 87ms/step - loss: 0.1690 - accuracy: 0.7911 - precision: 0.7689 - recall: 0.8291 - val_loss: 0.1618 - val_accuracy: 0.8057 - val_precision: 0.8122 - val_recall: 0.8148 - lr: 0.0010
# Epoch 6/1000
# 479/480 [============================>.] - ETA: 0s - loss: 0.1597 - accuracy: 0.7992 - precision: 0.7870 - recall: 0.8254
# Epoch 6: val_loss improved from 0.16175 to 0.15340, saving model to /app/_data/artist_data/models/test_arch/constr_7/model.h5
# 480/480 [==============================] - 42s 87ms/step - loss: 0.1597 - accuracy: 0.7992 - precision: 0.7871 - recall: 0.8253 - val_loss: 0.1534 - val_accuracy: 0.8125 - val_precision: 0.7986 - val_recall: 0.8399 - lr: 0.0010
# Epoch 7/1000
# 480/480 [==============================] - ETA: 0s - loss: 0.1527 - accuracy: 0.8083 - precision: 0.7976 - recall: 0.8166
# Epoch 7: val_loss improved from 0.15340 to 0.15224, saving model to /app/_data/artist_data/models/test_arch/constr_7/model.h5
# 480/480 [==============================] - 42s 87ms/step - loss: 0.1527 - accuracy: 0.8083 - precision: 0.7976 - recall: 0.8166 - val_loss: 0.1522 - val_accuracy: 0.8158 - val_precision: 0.8434 - val_recall: 0.7687 - lr: 0.0010
# Epoch 8/1000
# 479/480 [============================>.] - ETA: 0s - loss: 0.1485 - accuracy: 0.8093 - precision: 0.8040 - recall: 0.8149
# Epoch 8: val_loss improved from 0.15224 to 0.13861, saving model to /app/_data/artist_data/models/test_arch/constr_7/model.h5
# 480/480 [==============================] - 42s 86ms/step - loss: 0.1486 - accuracy: 0.8090 - precision: 0.8035 - recall: 0.8147 - val_loss: 0.1386 - val_accuracy: 0.8255 - val_precision: 0.8256 - val_recall: 0.8266 - lr: 0.0010
# Epoch 9/1000
# 480/480 [==============================] - ETA: 0s - loss: 0.1464 - accuracy: 0.8092 - precision: 0.8083 - recall: 0.8082
# Epoch 9: val_loss did not improve from 0.13861
# 480/480 [==============================] - 41s 84ms/step - loss: 0.1464 - accuracy: 0.8092 - precision: 0.8083 - recall: 0.8082 - val_loss: 0.1386 - val_accuracy: 0.8229 - val_precision: 0.8364 - val_recall: 0.8073 - lr: 0.0010
# Epoch 10/1000
# 251/480 [==============>...............] - ETA: 15s - loss: 0.1410 - accuracy: 0.8190 - precision: 0.8189 - recall: 0.8213

# %%
plot_history(history.history)

# %% [markdown]
# ## save

# %%
def save_params(mod_dir, model, history, cfg, loss="constr"):
    train_history = history.history
    min_val_loss_ix = np.argmin(train_history["val_loss"])
    max_acc = train_history["val_accuracy"][min_val_loss_ix]
    max_acc = int(np.round(max_acc * 1000))
    for k in train_history.keys():
        train_history[k] = list(map(float, train_history[k]))
    model.save(
        os.path.join(mod_dir, f"model_{max_acc}.h5"),
    )
    config = {
        "loss": loss,
        "pos_label": cfg.pos_label,
        "history": train_history,
        "norm": cfg.norm,
        "fold": cfg.fold,
        "model": {
            "eff": False,
            "input_shape": cfg.input_shape,
            "n_blocks": cfg.n_blocks,
            "embedding_len": cfg.emb_len,
            "kernel_size": cfg.kernel_size,
            "activation_fn": cfg.act_fn,
            "batch_norm": False,
        },
    }
    with open(os.path.join(mod_dir, "config.json"), "w") as f:
        json.dump(config, f)
    model.save(os.path.join(mod_dir, f"model_{max_acc}"), include_optimizer=False)
    print(
        f'Max_acc = {max_acc/1000}, model saved to {os.path.join(mod_dir, f"model_{max_acc}")}'
    )

# %%
save_params(mod_dir, model, history, cfg, loss="constr")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /app/_data/artist_data/models/test_arch/constr_6/model_865/assets
# INFO:tensorflow:Assets written to: /app/_data/artist_data/models/test_arch/constr_6/model_865/assets
# Max_acc = 0.865, model saved to /app/_data/artist_data/models/test_arch/constr_6/model_865

# %%
keras.utils.plot_model(
    mod,
    show_shapes=True,
    expand_nested=True,
)

# %%
mod = keras.models.load_model(
    "/app/_data/artist_data/models/test_arch/constr_6/model_865", compile=False
)

# %%
mod(imgs)
# Out:
# <tf.Tensor: shape=(32, 1), dtype=float32, numpy=
# array([[0.98003435],
#        [0.96090364],
#        [0.99565494],
#        [0.09353855],
#        [0.07183608],
#        [0.64381486],
#        [0.22625278],
#        [0.1011342 ],
#        [0.07094228],
#        [0.08936634],
#        [0.18291612],
#        [0.9040286 ],
#        [0.126618  ],
#        [0.77467144],
#        [0.30103597],
#        [0.44632876],
#        [0.607227  ],
#        [0.19414668],
#        [0.93546754],
#        [0.80576634],
#        [0.9836625 ],
#        [0.47596118],
#        [0.90914756],
#        [0.06013178],
#        [0.07615371],
#        [0.3776563 ],
#        [0.9862092 ],
#        [0.9925114 ],
#        [0.52822125],
#        [0.3246523 ],
#        [0.9674128 ],
#        [0.26738855]], dtype=float32)>

# %%
mod.get_output_at("dense_2048")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [53], line 1
# ----> 1 mod.get_output_at('dense_2048')
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:1872, in Layer.get_output_at(self, node_index)
#    1856 @doc_controls.do_not_doc_inheritable
#    1857 def get_output_at(self, node_index):
#    1858   """Retrieves the output tensor(s) of a layer at a given node.
#    1859
#    1860   Args:
#    (...)
#    1870     RuntimeError: If called in Eager mode.
#    1871   """
# -> 1872   return self._get_node_attribute_at_index(node_index, 'output_tensors',
#    1873                                            'output')
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:2718, in Layer._get_node_attribute_at_index(self, node_index, attr, attr_name)
#    2695 """Private utility to retrieves an attribute (e.g. inputs) from a node.
#    2696
#    2697 This is used to implement the methods:
#    (...)
#    2715     ValueError: If the index provided does not match any node.
#    2716 """
#    2717 if not self._inbound_nodes:
# -> 2718   raise RuntimeError(f'The layer {self.name} has never been called '
#    2719                      'and thus has no defined {attr_name}.')
#    2720 if not len(self._inbound_nodes) > node_index:
#    2721   raise ValueError(f'Asked to get {attr_name} at node '
#    2722                    f'{node_index}, but the layer has only '
#    2723                    f'{len(self._inbound_nodes)} inbound nodes.')
#
# RuntimeError: The layer model_3 has never been called and thus has no defined {attr_name}.

# %%
index = 0
for idx, layer in enumerate(mod.layers):
    layer.name
# Out:
# 'img1'
# 'img2'
# 'embedding'
# 'lambda_3'
# 'dense_3'

# %%
mod.inputs
# Out:
# [<KerasTensor: shape=(None, 512, 81, 1) dtype=float32 (created by layer 'img1')>,
#  <KerasTensor: shape=(None, 512, 81, 1) dtype=float32 (created by layer 'img2')>]

# %%
[layer.output for layer in mod.layers][2]
# Out:
# <KerasTensor: shape=(None, 2048) dtype=float32 (created by layer 'dense_2048')>

# %%
from tensorflow.keras import layers


extractor = keras.Model(inputs=mod.inputs,
                        outputs=[layer.output for layer in mod.layers])
# features = extractor(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [98], line 4
#       1 from tensorflow.keras import layers
# ----> 4 extractor = keras.Model(inputs=mod.inputs,
#       5                         outputs=[layer.output for layer in mod.layers])
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py:587, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     585 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     586 try:
# --> 587   result = method(self, *args, **kwargs)
#     588 finally:
#     589   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:148, in Functional.__init__(self, inputs, outputs, name, trainable, **kwargs)
#     145   if not all([functional_utils.is_input_keras_tensor(t)
#     146               for t in tf.nest.flatten(inputs)]):
#     147     inputs, outputs = functional_utils.clone_graph_nodes(inputs, outputs)
# --> 148 self._init_graph_network(inputs, outputs)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py:587, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     585 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     586 try:
# --> 587   result = method(self, *args, **kwargs)
#     588 finally:
#     589   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:232, in Functional._init_graph_network(self, inputs, outputs)
#     229   self._input_coordinates.append((layer, node_index, tensor_index))
#     231 # Keep track of the network's nodes and layers.
# --> 232 nodes, nodes_by_depth, layers, _ = _map_graph_network(
#     233     self.inputs, self.outputs)
#     234 self._network_nodes = nodes
#     235 self._nodes_by_depth = nodes_by_depth
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:998, in _map_graph_network(inputs, outputs)
#     996 for x in tf.nest.flatten(node.keras_inputs):
#     997   if id(x) not in computable_tensors:
# --> 998     raise ValueError(
#     999         f'Graph disconnected: cannot obtain value for tensor {x} '
#    1000         f'at layer "{layer.name}". The following previous layers '
#    1001         f'were accessed without issue: {layers_with_complete_input}')
#    1002 for x in tf.nest.flatten(node.outputs):
#    1003   computable_tensors.add(id(x))
#
# ValueError: Graph disconnected: cannot obtain value for tensor KerasTensor(type_spec=TensorSpec(shape=(None, 512, 81, 1), dtype=tf.float32, name='input_4'), name='input_4', description="created by layer 'input_4'") at layer "Conv2D_1". The following previous layers were accessed without issue: []

# %%
layer_name = "embedding"
intermediate_layer_model = keras.Model(
    inputs=mod.inputs, outputs=mod.get_layer(layer_name).outputs
)
# intermediate_output = intermediate_layer_model.predict(imgs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [96], line 2
#       1 layer_name = "embedding"
# ----> 2 intermediate_layer_model = keras.Model(
#       3     inputs=mod.inputs, outputs=mod.get_layer(layer_name).outputs
#       4 )
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py:587, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     585 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     586 try:
# --> 587   result = method(self, *args, **kwargs)
#     588 finally:
#     589   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:148, in Functional.__init__(self, inputs, outputs, name, trainable, **kwargs)
#     145   if not all([functional_utils.is_input_keras_tensor(t)
#     146               for t in tf.nest.flatten(inputs)]):
#     147     inputs, outputs = functional_utils.clone_graph_nodes(inputs, outputs)
# --> 148 self._init_graph_network(inputs, outputs)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py:587, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     585 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     586 try:
# --> 587   result = method(self, *args, **kwargs)
#     588 finally:
#     589   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:232, in Functional._init_graph_network(self, inputs, outputs)
#     229   self._input_coordinates.append((layer, node_index, tensor_index))
#     231 # Keep track of the network's nodes and layers.
# --> 232 nodes, nodes_by_depth, layers, _ = _map_graph_network(
#     233     self.inputs, self.outputs)
#     234 self._network_nodes = nodes
#     235 self._nodes_by_depth = nodes_by_depth
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:998, in _map_graph_network(inputs, outputs)
#     996 for x in tf.nest.flatten(node.keras_inputs):
#     997   if id(x) not in computable_tensors:
# --> 998     raise ValueError(
#     999         f'Graph disconnected: cannot obtain value for tensor {x} '
#    1000         f'at layer "{layer.name}". The following previous layers '
#    1001         f'were accessed without issue: {layers_with_complete_input}')
#    1002 for x in tf.nest.flatten(node.outputs):
#    1003   computable_tensors.add(id(x))
#
# ValueError: Graph disconnected: cannot obtain value for tensor KerasTensor(type_spec=TensorSpec(shape=(None, 512, 81, 1), dtype=tf.float32, name='input_4'), name='input_4', description="created by layer 'input_4'") at layer "Conv2D_1". The following previous layers were accessed without issue: []

# %%
layer_names = [layer.name for layer in model.layers]
layer_idx = layer_names.index("embedding")
layer_idx
# Out:
# 2

# %%
mod.get_layer(name='embedding', index=None).
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [76], line 1
# ----> 1 mod.get_layer(name='dense_2048', index=None)
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/training.py:2922, in Model.get_layer(self, name, index)
#    2920     if layer.name == name:
#    2921       return layer
# -> 2922   raise ValueError(f'No such layer: {name}. Existing layers are: '
#    2923                    f'{list(layer.name for layer in self.layers)}.')
#    2924 raise ValueError('Provide either a layer name or layer index at '
#    2925                  '`get_layer`.')
#
# ValueError: No such layer: dense_2048. Existing layers are: ['img1', 'img2', 'embedding', 'lambda_3', 'dense_3'].

# %%
mod.summary(
    line_length=None,
    positions=None,
    print_fn=None,
    expand_nested=True,
    show_trainable=True,
)
# Out:
# Model: "model_3"
# _____________________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to                     Trainable
# =============================================================================================================
#  img1 (InputLayer)              [(None, 512, 81, 1)  0           []                               Y
#                                 ]
#
#  img2 (InputLayer)              [(None, 512, 81, 1)  0           []                               Y
#                                 ]
#
#  embedding (Functional)         (None, 2048)         58897404    ['img1[0][0]',                   Y
#                                                                   'img2[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_4 (InputLayer)         [(None, 512, 81, 1)  0           []                               Y          |
# |                              ]                                                                            |
# |                                                                                                           |
# | Conv2D_1 (Conv2D)            (None, 508, 80, 4)   44          []                               Y          |
# |                                                                                                           |
# | avg_pool_1 (AveragePooling2D)  (None, 254, 40, 4)  0          []                               Y          |
# |                                                                                                           |
# | Conv2D_2 (Conv2D)            (None, 250, 39, 16)  656         []                               Y          |
# |                                                                                                           |
# | avg_pool_2 (AveragePooling2D)  (None, 125, 19, 16)  0         []                               Y          |
# |                                                                                                           |
# | Conv2D_3 (Conv2D)            (None, 121, 18, 64)  10304       []                               Y          |
# |                                                                                                           |
# | avg_pool_3 (AveragePooling2D)  (None, 60, 9, 64)  0           []                               Y          |
# |                                                                                                           |
# | Conv2D_4 (Conv2D)            (None, 56, 8, 256)   164096      []                               Y          |
# |                                                                                                           |
# | avg_pool_4 (AveragePooling2D)  (None, 28, 4, 256)  0          []                               Y          |
# |                                                                                                           |
# | flatten (Flatten)            (None, 28672)        0           []                               Y          |
# |                                                                                                           |
# | dense_2048 (Dense)           (None, 2048)         58722304    []                               Y          |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  lambda_3 (Lambda)              (None, 1)            0           ['embedding[0][0]',              Y
#                                                                   'embedding[1][0]']
#
#  dense_3 (Dense)                (None, 1)            2           ['lambda_3[0][0]']               Y
#
# =============================================================================================================
# Total params: 58,897,406
# Trainable params: 58,897,406
# Non-trainable params: 0
# _____________________________________________________________________________________________________________

# %%
mod.weights
# Out:
# [<tf.Variable 'Conv2D_1/kernel:0' shape=(5, 2, 1, 4) dtype=float32, numpy=
#  array([[[[-0.0874107 ,  0.0599575 , -0.57062316, -0.02954399]],
#
#          [[ 0.3045887 ,  0.13776264,  0.06934119,  0.33700562]]],
#
#
#         [[[ 0.23226811, -0.02713687, -0.22695085,  0.15844029]],
#
#          [[ 0.31330416,  0.2724804 , -0.1531786 , -0.15681589]]],
#
#
#         [[[ 0.04074979, -0.10129156, -0.3651662 ,  0.11254591]],
#
#          [[ 0.08808944, -0.25634363,  0.25680286, -0.0551444 ]]],
#
#
#         [[[-0.2128181 ,  0.34154415,  0.03257364,  0.09881572]],
#
#          [[-0.19144753,  0.13644049, -0.01524954, -0.00920989]]],
#
#
#         [[[-0.06335662,  0.16671474, -0.13847673, -0.19666527]],
#
#          [[-0.08257804, -0.1705138 , -0.059266  , -0.30527008]]]],
#        dtype=float32)>,
#  <tf.Variable 'Conv2D_1/bias:0' shape=(4,) dtype=float32, numpy=array([ 0.06295907,  0.11284952, -0.03575081,  0.01603395], dtype=float32)>,
#  <tf.Variable 'Conv2D_2/kernel:0' shape=(5, 2, 4, 16) dtype=float32, numpy=
#  array([[[[-1.75501585e-01, -2.45214835e-01, -1.73430368e-01,
#            -5.67379296e-02, -1.46311074e-01,  1.87304094e-01,
#             1.83067657e-02,  1.32165819e-01,  1.48024097e-01,
#            -1.68922633e-01,  2.46567324e-01,  2.05622129e-02,
#             2.61880681e-02,  2.82423794e-01,  5.16001694e-02,
#             2.08297655e-01],
#           [-1.94532484e-01, -9.45193246e-02, -7.86553621e-02,
#            -1.76519603e-01, -2.78684944e-01,  1.98070526e-01,
#            -1.34551749e-01,  2.12746263e-01,  9.79423597e-02,
#             7.06294831e-03,  2.86881030e-02, -8.91794488e-02,
#             1.87527329e-01,  3.38418558e-02,  7.19865188e-02,
#            -1.06032314e-02, -2.09489495e-01,  2.06653669e-01,
#             1.21572971e-01, -5.79013526e-02, -8.18358362e-02,
#            -1.28028870e-01],
#           [-3.70675549e-02, -6.94940537e-02, -2.01696754e-01,
#             1.65467560e-01,  2.12651074e-01,  2.26713598e-01,
#             5.09920530e-02,  1.76880002e-01, -7.81863555e-02,
#             1.05887130e-01,  9.12670940e-02, -1.81961000e-01,
#             1.27409428e-01, -1.93362340e-01, -1.11792117e-01,
#            -3.21612880e-02],
#           [ 1.07951492e-01,  1.57736093e-01,  9.44705531e-02,
#             4.31738868e-02,  1.58895895e-01, -1.40590638e-01,
#            -5.73004559e-02,  1.70794934e-01, -1.89051986e-01,
#            -2.65776645e-02,  6.80454075e-02, -4.48152386e-02,
#            -1.28631726e-01,  9.10886601e-02,  2.10983455e-02,
#             3.55551660e-01],
#           [-2.27820054e-01, -4.13025320e-02, -1.43958777e-01,
#             5.96774295e-02, -1.44281462e-01, -8.83956626e-02,
#            -4.49067689e-02, -2.11678934e-03,  1.36858612e-01,
#            -9.86301377e-02, -7.31779486e-02, -2.97869230e-03,
#            -3.28904837e-01,  6.48092702e-02, -1.40096873e-01,
#             8.42600241e-02]]]], dtype=float32)>,
#  <tf.Variable 'Conv2D_2/bias:0' shape=(16,) dtype=float32, numpy=
#  array([ 0.10929161,  0.00415226, -0.06276709,  0.11603378,  0.17208664,
#          0.15362243,  0.10260323,  0.07600162,  0.13759056, -0.04587225,
#          0.04620069,  0.17767261,  0.15011717,  0.05495454,  0.01773192,
#          0.1671578 ], dtype=float32)>,
#  <tf.Variable 'Conv2D_3/kernel:0' shape=(5, 2, 16, 64) dtype=float32, numpy=
#  array([[[[ 0.09233727, -0.07646143, -0.05831884, ..., -0.09800714,
#            -0.12262615,  0.06142646],
#           [ 0.01344905, -0.05308287, -0.08177631, ...,  0.06864141,
#            -0.06674075,  0.01332587],
#           [-0.08796076,  0.00098431,  0.06907479, ...,  0.01802583,
#            -0.02354974,  0.02720701],
#           ...,
#           [ 0.04783623, -0.07640497,  0.05402209, ...,  0.08676995,
#            -0.03523596, -0.08055943],
#           [ 0.02393472, -0.06457112, -0.06568989, ...,  0.09722513,
#            -0.11653692, -0.08478425],
#           [-0.09055579,  0.02060725,  0.01897092, ...,  0.07792007,
#             0.22117256,  0.04187785]],
#
#          [[ 0.07455289, -0.08754349, -0.07439421, ...,  0.01346005,
#            -0.18899965, -0.01795306],
#           [-0.16487293, -0.09044046, -0.01727708, ...,  0.06328456,
#            -0.05907515,  0.02052926],
#           [ 0.05445876, -0.05252329, -0.03826362, ...,  0.0203937 ,
#            -0.02328472,  0.03790563],
#           ...,
#           [-0.10310541,  0.06387369,  0.02414776, ...,  0.09246632,
#            -0.18858665, -0.01291596],
#           [ 0.03223867,  0.05666092, -0.06352238, ...,  0.0205707 ,
#            -0.21374153,  0.02696366],
#           [ 0.0207352 , -0.00738647, -0.05872539, ...,  0.0760142 ,
#             0.27124354,  0.04781028]]],
#
#
#         [[[-0.03634167, -0.03700688, -0.05401808, ..., -0.04662749,
#             0.12081532, -0.0317389 ],
#           [-0.09257839,  0.03299923, -0.06148909, ..., -0.04760808,
#            -0.09158291,  0.04693168],
#           [ 0.03537994, -0.01174276,  0.08079751, ..., -0.00094522,
#             0.01589593, -0.02608332],
#           ...,
#           [-0.01065195, -0.07307155,  0.01721906, ..., -0.03952209,
#             0.01266423,  0.01485353],
#           [ 0.05135697,  0.03261521,  0.0670519 , ...,  0.05950721,
#            -0.02857776,  0.06582259],
#           [-0.02139256, -0.06201712, -0.08404037, ...,  0.01131098,
#            -0.13429162, -0.10823555]],
#
#          [[ 0.03418526, -0.01932548, -0.05900536, ...,  0.06985214,
#             0.08783652,  0.01822584],
#           [-0.1193517 ,  0.00748125,  0.06816525, ...,  0.08149651,
#             0.02359319, -0.03713376],
#           [ 0.03744603,  0.07228594, -0.0119934 , ...,  0.04828724,
#            -0.04237656, -0.05125944],
#           ...,
#           [ 0.06662932,  0.02560167,  0.03265427, ...,  0.06700005,
#             0.06330281, -0.07112763],
#           [-0.03617588, -0.05147453, -0.0902718 , ..., -0.08794792,
#            -0.05131806, -0.01077388],
#           [-0.09315691,  0.01374724, -0.01159672, ...,  0.05283798,
#            -0.12709656, -0.03570129]]],
#
#
#         [[[-0.13532844,  0.01960791, -0.07474875, ..., -0.02711339,
#             0.23831555,  0.0408941 ],
#           [-0.02456   , -0.02739847,  0.01852104, ...,  0.00958229,
#            -0.00616325,  0.01226889],
#           [-0.01752138,  0.06218888, -0.04213819, ...,  0.0740898 ,
#             0.04748886, -0.04489911],
#           ...,
#           [ 0.02573897,  0.03080668, -0.08223931, ..., -0.01592646,
#            -0.07959905, -0.03327357],
#           [-0.07334186,  0.03140907,  0.07615788, ...,  0.04475357,
#            -0.17392217, -0.06190214],
#           [-0.0994482 , -0.04548568,  0.01824224, ...,  0.02071241,
#            -0.04599601,  0.06349473]],
#
#          [[ 0.00840817,  0.04801504, -0.00877024, ...,  0.04755004,
#             0.29870597, -0.07644571],
#           [-0.05941593,  0.01360733, -0.0552903 , ...,  0.09066881,
#            -0.11337183, -0.02390123],
#           [-0.02584265, -0.03767905,  0.02997003, ..., -0.08709268,
#            -0.00519778,  0.0190941 ],
#           ...,
#           [-0.02751882,  0.03822551,  0.05174442, ..., -0.06061415,
#            -0.12228212,  0.04117333],
#           [ 0.03577221,  0.04650141,  0.01870446, ..., -0.04932116,
#            -0.00457296, -0.0850445 ],
#           [-0.11203406, -0.01931845, -0.09405619, ..., -0.0954575 ,
#             0.05320347, -0.07414015]]],
#
#
#         [[[-0.08285513, -0.00468464,  0.02331874, ..., -0.04231795,
#            -0.19112387, -0.03454331],
#           [-0.0066072 ,  0.00661735, -0.0616329 , ...,  0.1001296 ,
#            -0.08118763, -0.06410186],
#           [-0.11443462,  0.00276081,  0.02968303, ...,  0.05360774,
#            -0.06979187,  0.03984994],
#           ...,
#           [ 0.05713086, -0.03568336, -0.0445177 , ...,  0.07934216,
#             0.10007883,  0.00276675],
#           [ 0.07530106, -0.08526139, -0.01160542, ...,  0.02729859,
#             0.12717728,  0.09462608],
#           [-0.13489877, -0.05204568,  0.02648892, ..., -0.01455209,
#             0.10456015, -0.08807272]],
#
#          [[-0.01891126, -0.06788328, -0.02498181, ...,  0.08122303,
#            -0.17964768, -0.05027325],
#           [ 0.03269729,  0.04991413, -0.00427859, ...,  0.0518931 ,
#            -0.00724694, -0.00646876],
#           [-0.09091019,  0.06833023, -0.06907146, ..., -0.00293271,
#            -0.09786664,  0.05080757],
#           ...,
#           [ 0.10804426,  0.05272929,  0.05623165, ..., -0.03782414,
#             0.36420164,  0.02655332],
#           [-0.02602937,  0.02539748, -0.07603392, ...,  0.01979876,
#             0.03595233, -0.03603942],
#           [-0.13169563, -0.02346302, -0.05542785, ...,  0.01832382,
#             0.11625291,  0.04181993]]],
#
#
#         [[[ 0.03941899, -0.02500443,  0.0350935 , ..., -0.14326976,
#             0.11066807, -0.00323064],
#           [-0.06238048, -0.08855101,  0.0411988 , ..., -0.05675171,
#            -0.08297633, -0.08116993],
#           [-0.04863507,  0.04529193,  0.03580401, ...,  0.03570843,
#             0.05010805,  0.03281908],
#           ...,
#           [-0.04725182, -0.0319418 ,  0.03162162, ...,  0.05291774,
#             0.12868123, -0.04221096],
#           [-0.04323912,  0.00166005,  0.07446975, ...,  0.07748875,
#            -0.09035613,  0.10123289],
#           [-0.11869968,  0.05748812,  0.03865932, ..., -0.08984508,
#            -0.16616537,  0.00765575]],
#
#          [[ 0.00194676,  0.07001382, -0.03160767, ..., -0.02206347,
#             0.22639833,  0.04245001],
#           [-0.02767228,  0.03599263,  0.03469376, ...,  0.0317168 ,
#            -0.19396546, -0.00824968],
#           [ 0.05102469,  0.0668567 ,  0.00446599, ..., -0.03457801,
#            -0.04007991, -0.04630079],
#           ...,
#           [-0.05336132,  0.04195273,  0.04526434, ...,  0.04469708,
#             0.06337118,  0.06962641],
#           [ 0.03265432, -0.02322079, -0.04288999, ...,  0.07177447,
#            -0.22605547, -0.01564341],
#           [-0.00375315, -0.00661001,  0.05984399, ..., -0.05204643,
#            -0.14348005,  0.02844978]]]], dtype=float32)>,
#  <tf.Variable 'Conv2D_3/bias:0' shape=(64,) dtype=float32, numpy=
#  array([-1.57255828e-02, -1.27398288e-02, -1.18140159e-02, -9.47943423e-03,
#         -1.48356650e-02, -1.73735316e-04,  1.02695927e-01,  1.39347509e-01,
#          4.53544362e-03,  2.50342816e-01, -1.43588092e-02, -1.25768920e-02,
#          9.42126960e-02,  3.61392409e-01,  1.10251252e-02,  1.23462036e-01,
#         -1.43240364e-02, -2.27109492e-02, -3.61406952e-02, -1.89099219e-02,
#         -3.97407934e-02,  1.91432074e-01, -2.06926875e-02,  2.90130883e-01,
#          6.81119487e-02, -1.08925672e-02, -2.16193069e-02, -2.28927191e-02,
#          2.09532395e-01, -1.66441612e-02, -5.42085385e-03,  3.88499378e-04,
#         -3.89317563e-03, -2.90890271e-03,  9.60589051e-02, -6.10418711e-03,
#         -3.61215584e-02, -1.92658119e-02, -4.15488612e-03, -2.80201044e-02,
#          5.91800199e-04,  2.53472030e-01, -2.29680017e-02, -1.44233862e-02,
#         -2.09567193e-02,  2.55010545e-01, -1.75161418e-02,  1.75983403e-02,
#         -2.52872407e-02, -2.30076481e-02, -1.22840023e-02, -1.15921656e-02,
#         -1.53801944e-02,  1.21708341e-01, -7.89390504e-03,  4.25285131e-01,
#         -1.55666741e-02, -1.05248308e-02,  3.75321321e-03,  5.28651243e-03,
#         -4.17871065e-02, -6.34938292e-03,  1.12872191e-01, -1.99838169e-02],
#        dtype=float32)>,
#  <tf.Variable 'Conv2D_4/kernel:0' shape=(5, 2, 64, 256) dtype=float32, numpy=
#  array([[[[-0.02216862,  0.02045029, -0.03379163, ..., -0.01220486,
#             0.02657262,  0.03156644],
#           [-0.0198096 , -0.01461895, -0.01131198, ...,  0.02017954,
#            -0.0434574 , -0.01691372],
#           [ 0.03620679, -0.00404282,  0.04260909, ...,  0.02455528,
#            -0.03017692,  0.01169594],
#           ...,
#           [ 0.015277  , -0.03762031,  0.02176359, ..., -0.01333061,
#            -0.02029709,  0.02156461],
#           [-0.08625598, -0.00843108, -0.01475116, ..., -0.02245811,
#             0.01535056, -0.03458546],
#           [ 0.02751293, -0.03007179,  0.01404948, ..., -0.04104054,
#            -0.02480456, -0.03477537]],
#
#          [[-0.01814148, -0.01482265,  0.01348589, ..., -0.03005477,
#             0.03205055,  0.02684879],
#           [-0.02626898, -0.03050498,  0.03516207, ..., -0.03049044,
#            -0.00598391, -0.03618056],
#           [ 0.00684762,  0.03260262, -0.00391107, ..., -0.03057386,
#             0.00092994,  0.00231127],
#           ...,
#           [ 0.03019628,  0.02018664,  0.01349977, ..., -0.00316566,
#            -0.01143405, -0.02395312],
#           [-0.04639463, -0.03396519, -0.01276191, ..., -0.00404525,
#             0.01132042, -0.04890676],
#           [ 0.04089013, -0.03575667,  0.00137865, ...,  0.02957538,
#            -0.02126027,  0.02355942]]],
#
#
#         [[[-0.01656108,  0.02504759, -0.03737635, ...,  0.01315389,
#            -0.03063555, -0.02071199],
#           [-0.00140532, -0.01826597, -0.0245131 , ...,  0.02690677,
#            -0.03148999, -0.00738288],
#           [ 0.01580494,  0.00155083, -0.01351418, ..., -0.04630683,
#            -0.02928685, -0.01952077],
#           ...,
#           [-0.00523355, -0.03583218,  0.01088652, ...,  0.00968219,
#            -0.00236895,  0.03890812],
#           [-0.03320454, -0.02907702,  0.02694169, ...,  0.01434347,
#             0.00840828, -0.04792944],
#           [ 0.0373694 ,  0.03820639, -0.01556627, ..., -0.03550519,
#            -0.02162769, -0.00394153]],
#
#          [[-0.02321125,  0.02925118, -0.03314979, ..., -0.04017935,
#             0.03886877, -0.03115941],
#           [ 0.02818521,  0.02605955, -0.0359804 , ...,  0.00967797,
#            -0.02472168, -0.02914489],
#           [-0.02784312,  0.00491596,  0.01318358, ..., -0.04708588,
#             0.00612198, -0.0194563 ],
#           ...,
#           [-0.02222114,  0.01100463,  0.03207071, ..., -0.0259624 ,
#            -0.02563911,  0.02685992],
#           [-0.0197101 ,  0.02716239, -0.03170525, ...,  0.00745301,
#             0.02066253, -0.01659959],
#           [-0.03409075, -0.02943529, -0.00601693, ..., -0.0301679 ,
#             0.02178926, -0.00716949]]],
#
#
#         [[[ 0.03261147,  0.005261  ,  0.00109055, ...,  0.02534444,
#            -0.03649426, -0.01186805],
#           [ 0.02613831, -0.03299055, -0.00375538, ..., -0.0239361 ,
#             0.00684929,  0.0498187 ],
#           [-0.00328349,  0.0084694 , -0.01271928, ..., -0.02964977,
#            -0.00169665,  0.02332216],
#           ...,
#           [-0.007897  ,  0.02390952, -0.00241985, ..., -0.03326168,
#             0.03219695,  0.03361405],
#           [-0.03026092,  0.03801097, -0.02918803, ...,  0.02481518,
#            -0.02385881, -0.03160856],
#           [-0.03059164, -0.04102023, -0.0407096 , ...,  0.0202035 ,
#             0.00076423, -0.0377081 ]],
#
#          [[ 0.01025049, -0.01471632,  0.03410106, ..., -0.01576137,
#             0.04015955,  0.00830434],
#           [ 0.00029582,  0.01688146,  0.0199376 , ..., -0.02860399,
#            -0.01379402,  0.03626511],
#           [ 0.00935978, -0.03253437, -0.03034889, ...,  0.02483861,
#            -0.03562514,  0.00670302],
#           ...,
#           [-0.0314782 ,  0.01055939, -0.00035464, ...,  0.02833823,
#            -0.0349621 ,  0.03566145],
#           [ 0.02687229,  0.03332534,  0.00865171, ...,  0.02912269,
#             0.02398564,  0.03272931],
#           [ 0.01547698, -0.01288719,  0.0364706 , ...,  0.00071976,
#             0.03662115, -0.03002536]]],
#
#
#         [[[ 0.03168547, -0.03988104, -0.02573267, ...,  0.02911615,
#            -0.02158862, -0.03978042],
#           [-0.02327788,  0.01089661, -0.04131982, ..., -0.00847411,
#             0.03349134,  0.02116233],
#           [-0.01632039,  0.02170965,  0.02273737, ...,  0.01464162,
#            -0.01339094,  0.01054351],
#           ...,
#           [ 0.02121597, -0.00100081,  0.03080785, ..., -0.04465181,
#             0.02524577,  0.01318076],
#           [ 0.04985243, -0.02094069,  0.02705171, ..., -0.02816875,
#            -0.00523346,  0.01255755],
#           [-0.00856804, -0.01071143,  0.02211823, ..., -0.00388418,
#             0.02033298,  0.01455867]],
#
#          [[-0.0003677 , -0.00716272, -0.0243    , ...,  0.02989854,
#            -0.01019201, -0.03287076],
#           [-0.01955322, -0.03732957,  0.03561784, ...,  0.03573216,
#            -0.00255127, -0.04066194],
#           [ 0.0369985 , -0.0018377 , -0.00492213, ..., -0.01805262,
#             0.01567696, -0.03707454],
#           ...,
#           [ 0.04252236, -0.01522748, -0.03960267, ..., -0.02322138,
#            -0.0420152 ,  0.04907823],
#           [ 0.00917388,  0.03682309,  0.01218955, ..., -0.0366183 ,
#            -0.02023582, -0.02533187],
#           [ 0.02119219, -0.02296099,  0.04037309, ..., -0.04369224,
#            -0.00508703,  0.02938507]]],
#
#
#         [[[ 0.02970939, -0.00654291, -0.03684228, ...,  0.01611711,
#             0.02853735,  0.00101288],
#           [ 0.01829671, -0.02091911,  0.02807231, ..., -0.03632713,
#             0.02040875,  0.04060543],
#          6.2866598e-02, -6.7100213e-03,  3.7449209e-03, -1.4627883e-02,
#         -4.3114293e-03, -4.7112610e-03, -6.0336236e-03, -8.0127567e-03,
#         -1.4509653e-02, -1.0233808e-02,  4.1593811e-03,  6.8427236e-03,
#         -1.1241377e-03, -1.6506016e-02, -5.1606363e-03, -1.0863821e-02,
#         -4.4078669e-03, -4.3715620e-03,  1.2628194e-02, -7.6877484e-03,
#         -9.1804024e-03, -6.0911216e-03,  3.9292253e-03, -9.2107803e-04],
#        dtype=float32)>,
#  <tf.Variable 'dense_2048/kernel:0' shape=(28672, 2048) dtype=float32, numpy=
#  array([[-0.00013211,  0.0113113 ,  0.02616955, ..., -0.00430996,
#          -0.00453304,  0.00781564],
#         [-0.00775438, -0.00091808,  0.01268215, ...,  0.00343878,
#           0.00943645,  0.00610611],
#         [-0.00508165, -0.00546504, -0.01222915, ..., -0.00111238,
#          -0.00879824, -0.01467382],
#         ...,
#         [ 0.0051966 ,  0.01101577, -0.01153207, ..., -0.01289999,
#          -0.00644007,  0.00593767],
#         [ 0.00454958, -0.01315096,  0.01287134, ..., -0.00666707,
#          -0.00729073, -0.01254803],
#         [ 0.00889936,  0.00584982,  0.01781039, ..., -0.00618739,
#           0.01459358,  0.01243091]], dtype=float32)>,
#  <tf.Variable 'dense_2048/bias:0' shape=(2048,) dtype=float32, numpy=
#  array([-0.00711934, -0.00581598,  0.00416266, ..., -0.00594053,
#          0.00049053, -0.00583829], dtype=float32)>,
#  <tf.Variable 'dense_3/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[0.5732861]], dtype=float32)>,
#  <tf.Variable 'dense_3/bias:0' shape=(1,) dtype=float32, numpy=array([-5.8588247], dtype=float32)>]

# %%
input = tf.keras.Input(shape=cfg.input_shape, dtype="float32")
x = keras.layers.Conv2D(
    4,
    cfg.kernel_size,
    activation=cfg.act_fn,
    name="Conv2D_1",
)(input)
x = keras.layers.AveragePooling2D(pool_size=(2, 2), name=f"avg_pool_1")(x)

x = keras.layers.Conv2D(
    filters=16,
    kernel_size=cfg.kernel_size,
    activation=cfg.act_fn,
    name="Conv2D_2",
)(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2), name=f"avg_pool_2")(x)

x = keras.layers.Conv2D(
    filters=64,
    kernel_size=cfg.kernel_size,
    activation=cfg.act_fn,
    name="Conv2D_3",
)(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2), name=f"avg_pool_3")(x)

x = keras.layers.Conv2D(
    filters=256,
    kernel_size=cfg.kernel_size,
    activation=cfg.act_fn,
    name="Conv2D_4",
)(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2), name=f"avg_pool_4")(x)


x = keras.layers.Flatten(name="flatten")(x)
x = keras.layers.Dense(cfg.emb_len, activation=cfg.act_fn, name=f"dense_{cfg.emb_len}")(
    x
)
embedding_net = keras.Model(inputs=input, outputs=x, name=f"embedding")

# %%
embedding_net.set_weights(mod.weights[:10],)

# %%
embedding_net(imgs['img1'])[0].numpy().sum()
# Out:
# 435.62268

# %%
d1 = embedding_net(imgs['img1'])
d2 = embedding_net(imgs['img2'])

# %%
np.argmax(euclidean_distance([d1, d2]).numpy())
# Out:
# 2

# %%
np.argmax(mod(imgs).numpy())
# Out:
# 2

# %%
plt.plot(np.arange(1,33), euclidean_distance([d1, d2]).numpy())

# %%
plt.plot(mod(imgs).numpy())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 plt.plot(mod(imgs).numpy())
#
# NameError: name 'plt' is not defined
