# %%
import glob
import os
import shutil

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.core.interactiveshell import InteractiveShell
from tqdm import tqdm

InteractiveShell.ast_node_interactivity = "all"

# %%
root_dir = "/app/_data/likes/"
track = pd.read_csv(os.path.join(root_dir, "track_artists.csv"))

# %%
track
# Out:
#         trackId  artistId
# 0         85862     52933
# 1        201387     11146
# 2        454079     38292
# 3        458287     50409
# 4        346334     24922
# ...         ...       ...
# 483270   444734     50780
# 483271   482562     27802
# 483272   287535     15106
# 483273   421598     31640
# 483274     6473      7783
#
# [483275 rows x 2 columns]

# %%
track['artistId'].unique().shape[0]
# Out:
# 56134

# %%
with open(os.path.join(root_dir, "train")) as f:
    train = [list(map(int, line.strip().split())) for line in f.readlines()]

# %%
len(train)
# Out:
# 1160084

# %%
n_tracks = [len(x) for x in train]

# %%
sns.histplot(n_tracks)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
np.min(n_tracks)
# Out:
# 7
